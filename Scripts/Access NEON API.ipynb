# %%
import requests
import json

# %%
SITECODE = "JORN" #the site code for Abby Road
PRODUCTCODE = "DP1.10022.001" #the product code for Ground beetles
SERVER = "http://data.neonscience.org/data-api/v0/"

# %%
SITECODE = "ABBY" #the site code for Abby Road
PRODUCTCODE = "DP1.10022.001" #the product code for Relative Humidity
SERVER = "http://data.neonscience.org/api/v0/" #the current server address

# %%
data_response = requests.get(SERVER + 'data/' + PRODUCTCODE)
data_response_json = data_response.json()
print(json.dumps(data_response_json, indent=2))
# Out:
# {
#   "error": {
#     "status": 400,
#     "detail": "Bad data request format."
#   }
# }

# %%
site_response = requests.get(SERVER + 'sites/' + SITECODE)

# %%
site_response_json = site_response.json()
print(json.dumps(site_response_json, indent=2)) #using json.dumps for formatting
# Out:
# {
#   "data": {
#     "domainName": "Pacific Northwest",
#     "dataProducts": [
#       {
#         "availableMonths": [
#           "2017-04",
#           "2017-05",
#           "2017-06"
#         ],
#         "dataProductCode": "DP1.00040.001",
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.00040.001/ABBY/2017-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00040.001/ABBY/2017-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00040.001/ABBY/2017-06"
#         ],
#         "dataProductTitle": "Soil heat flux plate"
#       },
#       {
#         "availableMonths": [
#           "2016-04",
#           "2016-05",
#           "2016-06",
#           "2016-07",
#           "2016-08",
#           "2016-09",
#           "2016-10",
#           "2016-11",
#           "2016-12",
#           "2017-01",
#           "2017-02",
#           "2017-03",
#           "2017-04",
#           "2017-05",
#           "2017-06"
# ...

# %%
theURL = "http://data.neonscience.org/browse-data" + _
"?p_p_id=neondatasearchavailabledata_WAR_neondatasearch&" + _
"p_p_lifecycle=2&" + _
"p_p_state=normal&" + _
"p_p_mode=view&" + _
"p_p_resource_id=datasetDownload&p_p_cacheability=cacheLevelPage&" + _ 
"p_p_col_id=column-1&" + _
"p_p_col_count=1&" + _
"startdate=2013-07-01&" + _
"enddate=2015-09-30&" + _
"dpcode=DP1.10022.001&pkgType=basic"
print theURL
# Out:
# http://data.neonscience.org/browse-datadpcode=DP1.10022.001&pkgType=basic
